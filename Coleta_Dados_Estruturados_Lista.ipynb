# %% [markdown]
# # Coleta de Dados Estruturados em lista de arquivos

# %% [markdown]
# Neste exercício, iremos coletar dados através de vários arquivos separados por data

# %%
#Importando as bibliotecas
import pandas as pd
import os

# %%
diretorio = 'C:\\IGTI_Data_Science\\Vendas veiculos\\dataset\\vendas_veiculos\\'

# %%
lista_path = os.listdir(diretorio)

# %%
lista_path[20:]
# Out:
# ['2020-11-14.csv',
#  '2020-11-16.csv',
#  '2020-11-17.csv',
#  '2020-11-18.csv',
#  '2020-11-19.csv',
#  '2020-11-20.csv',
#  '2020-11-21.csv',
#  '2020-11-22.csv',
#  '2020-11-23.csv',
#  '2020-11-24.csv',
#  '2020-11-25.csv',
#  '2020-11-26.csv',
#  '2020-11-27.csv',
#  '2020-11-28.csv',
#  '2020-11-29.csv',
#  '2020-11-30.csv',
#  '2020-12-11.csv',
#  '2020-12-12.csv',
#  '2020-12-13.csv',
#  '2020-12-14.csv',
#  '2020-12-15.csv',
#  '2020-12-17.csv',
#  '2020-12-18.csv',
#  '2020-12-19.csv',
#  '2020-12-20.csv',
#  '2020-12-22.csv',
#  '2020-12-23.csv',
#  '2020-12-24.csv',
#  '2020-12-25.csv',
#  '2020-12-26.csv',
#  '2020-12-27.csv',
#  '2020-12-28.csv',
#  '2020-12-29.csv',
#  '2020-12-31.csv',
#  '2021-01-01.csv',
#  '2021-01-02.csv',
#  '2021-01-13.csv',
#  '2021-01-14.csv',
#  '2021-01-15.csv',
#  '2021-01-17.csv',
#  '2021-01-18.csv',
#  '2021-01-19.csv',
#  '2021-01-20.csv',
#  '2021-01-21.csv',
#  '2021-01-22.csv',
#  '2021-01-23.csv',
#  '2021-01-24.csv',
#  '2021-01-25.csv',
#  '2021-01-27.csv',
#  '2021-01-28.csv',
#  '2021-01-29.csv',
#  '2021-01-31.csv',
#  '2021-02-01.csv',
#  '2021-03-01.csv',
#  '2021-04-01.csv',
#  '2021-05-01.csv',
#  '2021-07-01.csv',
#  '2021-08-01.csv',
#  '2021-09-01.csv',
#  '2021-10-01.csv',
#  '2021-11-01.csv',
#  '2021-12-01.csv',
#  'desktop.ini']

# %%
del(lista_path[-1])

# %%
lista_path
# Out:
# ['2020-01-12.csv',
#  '2020-02-11.csv',
#  '2020-02-12.csv',
#  '2020-03-11.csv',
#  '2020-03-12.csv',
#  '2020-04-11.csv',
#  '2020-05-11.csv',
#  '2020-05-12.csv',
#  '2020-06-11.csv',
#  '2020-06-12.csv',
#  '2020-07-11.csv',
#  '2020-07-12.csv',
#  '2020-08-12.csv',
#  '2020-09-11.csv',
#  '2020-09-12.csv',
#  '2020-10-11.csv',
#  '2020-10-12.csv',
#  '2020-11-11.csv',
#  '2020-11-12.csv',
#  '2020-11-13.csv',
#  '2020-11-14.csv',
#  '2020-11-16.csv',
#  '2020-11-17.csv',
#  '2020-11-18.csv',
#  '2020-11-19.csv',
#  '2020-11-20.csv',
#  '2020-11-21.csv',
#  '2020-11-22.csv',
#  '2020-11-23.csv',
#  '2020-11-24.csv',
#  '2020-11-25.csv',
#  '2020-11-26.csv',
#  '2020-11-27.csv',
#  '2020-11-28.csv',
#  '2020-11-29.csv',
#  '2020-11-30.csv',
#  '2020-12-11.csv',
#  '2020-12-12.csv',
#  '2020-12-13.csv',
#  '2020-12-14.csv',
#  '2020-12-15.csv',
#  '2020-12-17.csv',
#  '2020-12-18.csv',
#  '2020-12-19.csv',
#  '2020-12-20.csv',
#  '2020-12-22.csv',
#  '2020-12-23.csv',
#  '2020-12-24.csv',
#  '2020-12-25.csv',
#  '2020-12-26.csv',
#  '2020-12-27.csv',
#  '2020-12-28.csv',
#  '2020-12-29.csv',
#  '2020-12-31.csv',
#  '2021-01-01.csv',
#  '2021-01-02.csv',
#  '2021-01-13.csv',
#  '2021-01-14.csv',
#  '2021-01-15.csv',
#  '2021-01-17.csv',
#  '2021-01-18.csv',
#  '2021-01-19.csv',
#  '2021-01-20.csv',
#  '2021-01-21.csv',
#  '2021-01-22.csv',
#  '2021-01-23.csv',
#  '2021-01-24.csv',
#  '2021-01-25.csv',
#  '2021-01-27.csv',
#  '2021-01-28.csv',
#  '2021-01-29.csv',
#  '2021-01-31.csv',
#  '2021-02-01.csv',
#  '2021-03-01.csv',
#  '2021-04-01.csv',
#  '2021-05-01.csv',
#  '2021-07-01.csv',
#  '2021-08-01.csv',
#  '2021-09-01.csv',
#  '2021-10-01.csv',
#  '2021-11-01.csv',
#  '2021-12-01.csv']

# %%
lista_df = []
for arquivo in lista_path:
    local_arquivo = os.path.join(diretorio,arquivo)
    df = pd.read_csv(local_arquivo, sep=';',encoding='latin-1')
    lista_df.append(df)
df_vendas = pd.concat(lista_df)

# %%
df_vendas[:203]
# Out:
#     cod_pessoa           nome     genero data_nascimento data_compra  \
# 0         1016    Maria Clara   Feminino      1986-11-21  2020-01-12
# 0         1061         Bianca   Feminino      1989-02-21  2020-02-11
# 1         1086          Analu   Feminino      1977-08-05  2020-02-11
# 2         1117         Samuel  Masculino      1989-11-22  2020-02-11
# 3         1139           Cauã  Masculino      1961-09-14  2020-02-11
# ..         ...            ...        ...             ...         ...
# 3         1167           Ryan  Masculino      1996-10-21  2021-10-01
# 0         1100         Miguel  Masculino      1986-08-29  2021-11-01
# 0         1031        Lavínia   Feminino      1987-04-19  2021-12-01
# 1         1043         Alícia   Feminino      1965-07-05  2021-12-01
# 2         1082  Maria Heloísa   Feminino      1954-10-21  2021-12-01
#
#     fabricante               modelo  valor
# 0         Fiat   Uno Attractive 1.0  50004
# 0         Fiat        Mobi Easy 1.5  40449
# 1   Volkswagen      Fox Connect 1.6  57640
# 2         Fiat   Uno Attractive 1.0  50004
# 3        Lifan       530 Talent 1.5  43990
# ..         ...                  ...    ...
# 3   Volkswagen      Fox Connect 1.6  57640
# 0   Volkswagen      Fox Connect 1.6  57640
# 0         Fiat   Uno Attractive 1.0  50004
# 1   Volkswagen              Gol 1.0  54150
# 2         Fiat        Mobi Easy 1.5  40449
#
# [200 rows x 8 columns]

# %% [markdown]
# # Exportando Dados para arquivos

# %%
df_vendas.to_csv(diretorio + 'vendas_por_data.csv', sep=';', encoding='latin-1', index=False)

# %% [markdown]
# Agora temos os dados das vendas em um único arquivo

# %% [markdown]
# # Armazenando os dados no banco de dados MySQL

# %%
#Instalando as bibliotecas necessárias para trabalhar no banco
# !pip install mysqlclient
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: mysqlclient in c:\igti_data_science\env\coleta_dados\lib\site-packages (2.0.3)
# Requirement already satisfied: sqlalchemy in c:\igti_data_science\env\coleta_dados\lib\site-packages (1.4.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\igti_data_science\env\coleta_dados\lib\site-packages (from sqlalchemy) (1.0.0)

# %%
import MySQLdb
import sqlalchemy

# %%
user = 'root'
password = '383967739DARA'
host = 'localhost'
database = 'coletaIGTI' #schema

string_conexao = f'mysql://{user}:{password}@{host}/{database}'
string_conexao
# Out:
# 'mysql://root:383967739DARA@localhost/coletaIGTI'

# %%
engine = sqlalchemy.create_engine(string_conexao)
conn = engine.connect()

# %% [markdown]
# Preparando os dados para inserir nas tabelas

# %%
df_pessoas = df_vendas[['cod_pessoa', 'nome', 'genero', 'data_nascimento']].drop_duplicates()
df_modelos = df_vendas[['modelo','fabricante']].drop_duplicates()
fabricantes = list(df_vendas.fabricante.unique())

# %%
df_pessoas[:10]
# Out:
#    cod_pessoa          nome     genero data_nascimento
# 0        1016   Maria Clara   Feminino      1986-11-21
# 0        1061        Bianca   Feminino      1989-02-21
# 1        1086         Analu   Feminino      1977-08-05
# 2        1117        Samuel  Masculino      1989-11-22
# 3        1139          Cauã  Masculino      1961-09-14
# 0        1118  Enzo Gabriel  Masculino      1984-02-15
# 0        1048        Maria-   Feminino      1992-09-18
# 1        1050     Ana Laura   Feminino      1997-10-15
# 2        1075        Mariah   Feminino      1969-11-05
# 3        1092   Ana Vitória   Feminino      1963-12-05

# %%
df_modelos
# Out:
#                       modelo  fabricante
# 0         Uno Attractive 1.0        Fiat
# 0              Mobi Easy 1.5        Fiat
# 1            Fox Connect 1.6  Volkswagen
# 3             530 Talent 1.5       Lifan
# 0                   Ka S 1.0        Ford
# 0     Hyundai HB20 1.0 Sense      Hyndai
# 2                    Gol 1.0  Volkswagen
# 4  Grand Siena Attractive 1.        Fiat
# 0              Kwid Life 1.0     Renault
# 0                   Argo 1.0        Fiat

# %%
fabricantes
# Out:
# ['Fiat', 'Volkswagen', 'Lifan', 'Ford', 'Hyndai', 'Renault']

# %%
for pessoa in df_pessoas[:3].itertuples():
    print(pessoa)
# Out:
# Pandas(Index=0, cod_pessoa=1016, nome='Maria Clara', genero='Feminino', data_nascimento='1986-11-21')
# Pandas(Index=0, cod_pessoa=1061, nome='Bianca', genero='Feminino', data_nascimento='1989-02-21')
# Pandas(Index=1, cod_pessoa=1086, nome='Analu', genero='Feminino', data_nascimento='1977-08-05')

# %%
for pessoa in df_pessoas.itertuples():
    cod_pessoa = pessoa.cod_pessoa
    nome = pessoa.nome
    genero = pessoa.genero
    data_nascimento = str(pessoa.data_nascimento)
    try:
        query = f"""insert into pessoa (cod_pessoa, nome, genero, data_nascimento) 
                    values ('{cod_pessoa}', '{nome}', '{genero}', '{data_nascimento}')"""
        conn.execute(query)
        print(f"Registro inserido com sucesso: {nome}")
    except Exception as e:
        print(f"Não foi possível inserir o registro {nome}. O erro encontrado foi: {e}")
# Out:
# Registro inserido com sucesso: Maria Clara
# Registro inserido com sucesso: Bianca
# Registro inserido com sucesso: Analu
# Registro inserido com sucesso: Samuel
# Registro inserido com sucesso: Cauã
# Registro inserido com sucesso: Enzo Gabriel
# Registro inserido com sucesso: Maria-
# Registro inserido com sucesso: Ana Laura
# Registro inserido com sucesso: Mariah
# Registro inserido com sucesso: Ana Vitória
# Registro inserido com sucesso: José
# Registro inserido com sucesso: Alice
# Registro inserido com sucesso: Lara
# Registro inserido com sucesso: Luana
# Registro inserido com sucesso: Martin
# Registro inserido com sucesso: Ana Júlia
# Registro inserido com sucesso: Vicente
# Registro inserido com sucesso: Lucas
# Registro inserido com sucesso: Antônio
# Registro inserido com sucesso: Letícia
# Registro inserido com sucesso: Davi Luiz
# Registro inserido com sucesso: Yasmin
# Registro inserido com sucesso: Lorenzo
# Registro inserido com sucesso: Nicole
# Registro inserido com sucesso: Pedro Henrique
# Registro inserido com sucesso: Gael
# Registro inserido com sucesso: Kaique
# Registro inserido com sucesso: Ana Liz
# Registro inserido com sucesso: Luiz Felipe
# Registro inserido com sucesso: Maria Valentina
# Registro inserido com sucesso: Pedro
# Registro inserido com sucesso: Augusto
# Registro inserido com sucesso: Thiago
# Registro inserido com sucesso: Eloá
# Registro inserido com sucesso: Larissa
# Registro inserido com sucesso: Enzo Miguel
# Registro inserido com sucesso: Luiza
# Registro inserido com sucesso: Melissa
# Registro inserido com sucesso: Benício
# Registro inserido com sucesso: Luiz Otávio
# Registro inserido com sucesso: Agatha
# Registro inserido com sucesso: Arthur
# Registro inserido com sucesso: Gustavo
# Registro inserido com sucesso: Emilly
# Registro inserido com sucesso: Bryan
# Registro inserido com sucesso: Maria Alice
# Registro inserido com sucesso: Maria Helena
# Registro inserido com sucesso: Isabelly
# Registro inserido com sucesso: Arthur Gabriel
# Registro inserido com sucesso: Catarina
# Registro inserido com sucesso: Isaac
# Registro inserido com sucesso: Arthur Henrique
# Registro inserido com sucesso: Mirella
# Registro inserido com sucesso: Antônia
# Registro inserido com sucesso: Davi
# Registro inserido com sucesso: Emanuel
# Registro inserido com sucesso: Luiz Miguel
# Registro inserido com sucesso: João Miguel
# Registro inserido com sucesso: Isadora
# Registro inserido com sucesso: Rafael
# Registro inserido com sucesso: Bento
# Registro inserido com sucesso: Giovanna
# Registro inserido com sucesso: Enrico
# Registro inserido com sucesso: Thomas
# Registro inserido com sucesso: Kauê
# Registro inserido com sucesso: Lorena
# Registro inserido com sucesso: Isis
# Registro inserido com sucesso: Heitor
# Registro inserido com sucesso: Ayla
# Registro inserido com sucesso: João
# Registro inserido com sucesso: Amanda
# Registro inserido com sucesso: Maria Isis
# Registro inserido com sucesso: João Pedro
# Registro inserido com sucesso: Davi Miguel
# Registro inserido com sucesso: Luiz Henrique
# Registro inserido com sucesso: Isabella
# Registro inserido com sucesso: Maya
# Registro inserido com sucesso: Stella
# Registro inserido com sucesso: Lucas Gabriel
# Registro inserido com sucesso: Ana Sophia
# Registro inserido com sucesso: Victor
# Registro inserido com sucesso: Pedro Miguel
# Registro inserido com sucesso: Maria Júlia
# Registro inserido com sucesso: Clarice
# Registro inserido com sucesso: Malu
# Registro inserido com sucesso: Clara
# Registro inserido com sucesso: Murilo
# Registro inserido com sucesso: André
# Registro inserido com sucesso: Otávio
# Registro inserido com sucesso: Miguel Henrique
# Registro inserido com sucesso: Vinícius
# Registro inserido com sucesso: Nathan
# Registro inserido com sucesso: Danilo
# Registro inserido com sucesso: Leonardo
# Registro inserido com sucesso: Laís
# Registro inserido com sucesso: Heloise
# Registro inserido com sucesso: Benjamin
# Registro inserido com sucesso: João Guilherme
# Registro inserido com sucesso: Noah
# Registro inserido com sucesso: Ian
# Registro inserido com sucesso: Nicolas
# Registro inserido com sucesso: Victor Hugo
# Registro inserido com sucesso: Luiz Gustavo
# Registro inserido com sucesso: Laura
# Registro inserido com sucesso: João Victor
# Registro inserido com sucesso: Levi
# Registro inserido com sucesso: Lívia
# Registro inserido com sucesso: Maitê
# Registro inserido com sucesso: Carolina
# Registro inserido com sucesso: Raul
# Registro inserido com sucesso: Sophia
# Registro inserido com sucesso: Bruna
# Registro inserido com sucesso: Tomás
# Registro inserido com sucesso: Olívia
# Registro inserido com sucesso: Joana
# Registro inserido com sucesso: Valentina
# Registro inserido com sucesso: Maria Fernanda
# Registro inserido com sucesso: Maria Flor
# Registro inserido com sucesso: Pietra
# Registro inserido com sucesso: João Lucas
# Registro inserido com sucesso: Elisa
# Registro inserido com sucesso: Vitória
# Registro inserido com sucesso: Maria Vitória
# Registro inserido com sucesso: Maria Laura
# Registro inserido com sucesso: Anthony Gabriel
# Registro inserido com sucesso: Mariana
# Registro inserido com sucesso: Aurora
# Registro inserido com sucesso: Eduardo
# Registro inserido com sucesso: Heloísa
# Registro inserido com sucesso: Enzo
# Registro inserido com sucesso: Luan
# Registro inserido com sucesso: Rodrigo
# Registro inserido com sucesso: Ana Luiza
# Registro inserido com sucesso: Matheus
# Registro inserido com sucesso: Fernanda
# Registro inserido com sucesso: Maria Sophia
# Registro inserido com sucesso: Arthur Miguel
# Registro inserido com sucesso: Júlia
# Registro inserido com sucesso: Antonella
# Registro inserido com sucesso: Rafaela
# Registro inserido com sucesso: Beatriz
# Registro inserido com sucesso: Emanuelly
# Registro inserido com sucesso: Louise
# Registro inserido com sucesso: Daniel
# Registro inserido com sucesso: Erick
# Registro inserido com sucesso: Ruan
# Registro inserido com sucesso: Luna
# Registro inserido com sucesso: Gabrielly
# Registro inserido com sucesso: Pedro Lucas
# Registro inserido com sucesso: Felipe
# Registro inserido com sucesso: Théo
# Registro inserido com sucesso: Anthony
# Registro inserido com sucesso: Sarah
# Registro inserido com sucesso: Ana Lívia
# Registro inserido com sucesso: Eduarda
# Registro inserido com sucesso: Ana Cecília
# Registro inserido com sucesso: Gabriel
# Registro inserido com sucesso: Manuela
# Registro inserido com sucesso: Ana Clara
# Registro inserido com sucesso: Oliver
# Registro inserido com sucesso: Sophie
# Registro inserido com sucesso: Liz
# Registro inserido com sucesso: Isabel
# Registro inserido com sucesso: Bernardo
# Registro inserido com sucesso: Maria Luiza
# Registro inserido com sucesso: Rebeca
# Registro inserido com sucesso: Maria Eduarda
# Registro inserido com sucesso: João Gabriel
# Registro inserido com sucesso: Allana
# Registro inserido com sucesso: Francisco
# Registro inserido com sucesso: Caleb
# Registro inserido com sucesso: Joaquim
# Registro inserido com sucesso: Davi Lucca
# Registro inserido com sucesso: Bruno
# Registro inserido com sucesso: Guilherme
# Registro inserido com sucesso: Ana
# Registro inserido com sucesso: Lucca
# Registro inserido com sucesso: Milena
# Registro inserido com sucesso: Fernando
# Registro inserido com sucesso: Carlos Eduardo
# Registro inserido com sucesso: Henry
# Registro inserido com sucesso: Yago
# Registro inserido com sucesso: Esther
# Registro inserido com sucesso: Marina
# Registro inserido com sucesso: Gabriela
# Registro inserido com sucesso: Ana Beatriz
# Registro inserido com sucesso: Henrique
# Registro inserido com sucesso: Caio
# Registro inserido com sucesso: Yuri
# Registro inserido com sucesso: Breno
# Registro inserido com sucesso: Cecília
# Registro inserido com sucesso: Pietro
# Registro inserido com sucesso: Helena
# Registro inserido com sucesso: Maria Cecília
# Registro inserido com sucesso: Davi Lucas
# Registro inserido com sucesso: Ryan
# Registro inserido com sucesso: Miguel
# Registro inserido com sucesso: Lavínia
# Registro inserido com sucesso: Alícia
# Registro inserido com sucesso: Maria Heloísa

# %%
for fabricante in fabricantes:
    try:
        query = f"""insert into fabricante (nome_fabricante)
                     values ('{fabricante}')"""
        conn.execute(query)
        print(f"Registro inserido com sucesso: {fabricante}")
    except Exception as e:
        print(f"Não foi possível inserir o registro {fabricante}. O erro encontrado foi: {e}")
# Out:
# Registro inserido com sucesso: Fiat
# Registro inserido com sucesso: Volkswagen
# Registro inserido com sucesso: Lifan
# Registro inserido com sucesso: Ford
# Registro inserido com sucesso: Hyndai
# Registro inserido com sucesso: Renault

# %%
df_fabricante = pd.read_sql('fabricante', con=conn)

# %%
df_fabricante
# Out:
#    cod_fabricante nome_fabricante
# 0               1            Fiat
# 1               4            Ford
# 2               5          Hyndai
# 3               3           Lifan
# 4               6         Renault
# 5               2      Volkswagen

# %%
dict_fabricante = df_fabricante.set_index(df_fabricante.nome_fabricante)['cod_fabricante'].to_dict()
dict_fabricante
# Out:
# {'Fiat': 1, 'Ford': 4, 'Hyndai': 5, 'Lifan': 3, 'Renault': 6, 'Volkswagen': 2}

# %%
df_modelos.fabricante = df_modelos.fabricante.map(dict_fabricante)
df_modelos
# Out:
#                       modelo  fabricante
# 0         Uno Attractive 1.0           1
# 0              Mobi Easy 1.5           1
# 1            Fox Connect 1.6           2
# 3             530 Talent 1.5           3
# 0                   Ka S 1.0           4
# 0     Hyundai HB20 1.0 Sense           5
# 2                    Gol 1.0           2
# 4  Grand Siena Attractive 1.           1
# 0              Kwid Life 1.0           6
# 0                   Argo 1.0           1

# %%
df_modelos = df_modelos.rename(columns={'fabricante':'cod_fabricante'})
df_modelos
# Out:
#                       modelo  cod_fabricante
# 0         Uno Attractive 1.0               1
# 0              Mobi Easy 1.5               1
# 1            Fox Connect 1.6               2
# 3             530 Talent 1.5               3
# 0                   Ka S 1.0               4
# 0     Hyundai HB20 1.0 Sense               5
# 2                    Gol 1.0               2
# 4  Grand Siena Attractive 1.               1
# 0              Kwid Life 1.0               6
# 0                   Argo 1.0               1

# %%
for modelo in df_modelos.itertuples():
    nome_modelo = modelo.modelo
    cod_fabricante = modelo.cod_fabricante
    try:
        query = f"""insert into modelo_veiculo (descricao_modelo, cod_fabricante)
                    values ('{nome_modelo}', '{cod_fabricante}')"""
        conn.execute(query)
        print(f"Registro inserido com sucesso: {nome_modelo}")
    except Exception as e:
        print(f"Não foi possível inserir o registro: {nome_modelo}. O erro encontrado foi: {e}")
# Out:
# Registro inserido com sucesso:  Uno Attractive 1.0
# Registro inserido com sucesso: Mobi Easy 1.5
# Registro inserido com sucesso:  Fox Connect 1.6
# Registro inserido com sucesso: 530 Talent 1.5
# Registro inserido com sucesso: Ka S 1.0
# Registro inserido com sucesso: Hyundai HB20 1.0 Sense
# Registro inserido com sucesso:  Gol 1.0
# Registro inserido com sucesso: Grand Siena Attractive 1.
# Registro inserido com sucesso: Kwid Life 1.0
# Registro inserido com sucesso: Argo 1.0

# %% [markdown]
# # Criando uma tabela Staging no banco de dados

# %%
df_vendas.to_sql('stg_venda_veiculos', con=conn, schema='coletaIGTI')

# %% [markdown]
# Através de uma consulta SQL foi feito o preenchimento e normalização da tabela venda_veiculo

# %% [markdown]
# ![image.png](attachment:image.png)
