# %%
#importa a biblioteca que cria a sessão do spark
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#inicia a sessão para a utilização do spark
spark = SparkSession.builder.appName("RegressaoLinear").getOrCreate() #cria a seção caso não exista ou obtém a já criada
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Modulo4/</td><td>Modulo4/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/adult_data.csv</td><td>adult_data.csv</td><td>5608318</td></tr><tr><td>dbfs:/FileStore/tables/aula_2_TPD.ipynb</td><td>aula_2_TPD.ipynb</td><td>174755</td></tr><tr><td>dbfs:/FileStore/tables/cap2/</td><td>cap2/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/cap3/</td><td>cap3/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/cap4/</td><td>cap4/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/cap5/</td><td>cap5/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/cap6/</td><td>cap6/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/regressaoLinear.csv</td><td>regressaoLinear.csv</td><td>564</td></tr></tbody></table></div>

# %%
#diretório que contém o arquivo a ser utilizado
diretorioRegressao="/FileStore/tables/regressaoLinear.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#definindo o esquema dos dados a serem lidos
from pyspark.sql.types import *  #import dos tipos
schema=StructType().add("X",IntegerType(),True).add("Y",StringType(),True)  #define o esquema a ser utilizado
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#lendo arquivos armazenados CSV com o esquema definido
pagamentoSeguro = spark.read.format('csv').schema(schema).options(header='true',delimiter=';').load(diretorioRegressao)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagamentoSeguro.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- X: integer (nullable = true)
# -- Y: string (nullable = true)
#
# </div>

# %%
pagamentoSeguro.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+
#   X|    Y|
# +---+-----+
# 108|392,5|
#  19| 46,2|
#  13| 15,7|
# 124|422,2|
#  40|119,4|
# +---+-----+
# only showing top 5 rows
#
# </div>

# %%
import pyspark.sql.functions as F
pagamentoSeguro=pagamentoSeguro.select(F.col('X').alias("Apolices"), F.col('Y').alias("Valor_Pago"))  #adiciona nomes ao cabaçalho
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagamentoSeguro.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+----------+
# Apolices|Valor_Pago|
# +--------+----------+
#      108|     392,5|
#       19|      46,2|
#       13|      15,7|
#      124|     422,2|
#       40|     119,4|
# +--------+----------+
# only showing top 5 rows
#
# </div>

# %%
pagamentoSeguroPonto=pagamentoSeguro.withColumn("Valor_Pago_Novo", F.regexp_replace(F.col("Valor_Pago"), "[,]", "."))  #troca o valor de "," para "."
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagamentoSeguroPonto.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+----------+---------------+
# Apolices|Valor_Pago|Valor_Pago_Novo|
# +--------+----------+---------------+
#      108|     392,5|          392.5|
#       19|      46,2|           46.2|
#       13|      15,7|           15.7|
#      124|     422,2|          422.2|
#       40|     119,4|          119.4|
# +--------+----------+---------------+
# only showing top 5 rows
#
# </div>

# %%
#modificando o tipo string para numérico
pagamentoSeguroFinal=pagamentoSeguroPonto.select(F.col('Apolices'),F.col('Valor_Pago_Novo'), pagamentoSeguroPonto.Valor_Pago_Novo.cast('float').alias('Valor_Pago_Float'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pagamentoSeguroFinal.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------------+----------------+
# Apolices|Valor_Pago_Novo|Valor_Pago_Float|
# +--------+---------------+----------------+
#      108|          392.5|           392.5|
#       19|           46.2|            46.2|
#       13|           15.7|            15.7|
#      124|          422.2|           422.2|
#       40|          119.4|           119.4|
# +--------+---------------+----------------+
# only showing top 5 rows
#
# </div>

# %%
pagamentoSeguroFinal.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Apolices: integer (nullable = true)
# -- Valor_Pago_Novo: string (nullable = true)
# -- Valor_Pago_Float: float (nullable = true)
#
# </div>

# %% [markdown]
# Iniciando o Processo de Regressão

# %%
pagamentoSeguroFinal.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+-----------------+-----------------+
# summary|          Apolices|  Valor_Pago_Novo| Valor_Pago_Float|
# +-------+------------------+-----------------+-----------------+
#   count|                63|               63|               63|
#    mean|22.904761904761905|98.18730158730159|98.18730196877131|
#  stddev| 23.35194561605733|87.32755263404981|87.32755386147541|
#     min|                 0|                0|              0.0|
#     max|               124|             98.1|            422.2|
# +-------+------------------+-----------------+-----------------+
#
# </div>

# %%
#transformando os dados (linhas) em vetores
from pyspark.ml.feature import VectorAssembler  #importando a biblioteca responsável por criar o vetor a partir da coluna

assembler = VectorAssembler(inputCols=['Apolices'], outputCol='features')  #define o objeto para transformação
df_seguro = assembler.transform(pagamentoSeguroFinal) #aplica a transformação
df_seguro.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Apolices: integer (nullable = true)
# -- Valor_Pago_Novo: string (nullable = true)
# -- Valor_Pago_Float: float (nullable = true)
# -- features: vector (nullable = true)
#
# </div>

# %%
df_seguro = df_seguro.select(['features','Valor_Pago_Float'])
df_seguro.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+----------------+
# features|Valor_Pago_Float|
# +--------+----------------+
#  [108.0]|           392.5|
#   [19.0]|            46.2|
#   [13.0]|            15.7|
#  [124.0]|           422.2|
#   [40.0]|           119.4|
# +--------+----------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# Criando o Modelo de Regressão

# %%
from pyspark.ml.regression import LinearRegression  #biblioteca que contém o modelo de regressão

lr = LinearRegression(maxIter=10, labelCol='Valor_Pago_Float') #define o objeto a ser utilizado para regressão
lrModel = lr.fit(df_seguro)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Coeficientes angulares e lineares (a e b) da reta de regressão
print(f'Intercepto: {lrModel.intercept}\nCoeficiente Angular: {lrModel.coefficients.values}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Intercepto: 19.994485035718697
# Coeficiente Angular: [3.41382361]
# </div>

# %%
#estatísticas do modelo
modelsummary = lrModel.summary

print("Variância Explicada:", modelsummary.explainedVariance)
print('R_2: ', modelsummary.r2)
print('Erro médio quadrático: ',modelsummary.meanSquaredError)

modelsummary.residuals.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Variância Explicada: 6254.310467068246
# R_2:  0.8333466721037774
# Erro médio quadrático:  1250.7419636077982
# +-------------------+
#           residuals|
# +-------------------+
#  3.8125652674761454|
#  -38.65713283055052|
#  -48.67419213440233|
# -21.108600258352624|
#  -37.14742784198987|
# +-------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# Realizando a Previsão Através do Modelo

# %%
modelsummary.predictions.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------------------+------------------+
# features|  Valor_Pago_Float|        prediction|
# +--------+------------------+------------------+
#  [108.0]|             392.5|388.68743473252385|
#   [19.0]| 46.20000076293945| 84.85713359348998|
#   [13.0]|15.699999809265137| 64.37419194366747|
#  [124.0]|422.20001220703125| 443.3086124653839|
#   [40.0]| 119.4000015258789|156.54742936786877|
# +--------+------------------+------------------+
# only showing top 5 rows
#
# </div>
